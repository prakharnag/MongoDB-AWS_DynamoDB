# %%
from pymongo import MongoClient, ReadPreference
import pandas as pd
import time

# MongoDB setup
client = MongoClient('mongodb://localhost:27017')  
db = client['MongoDB']  
collection = 'NetflixUserbase'

# %%
# Load the dataset
data_path = "Netflix Userbase.csv"
df = pd.read_csv(data_path)

# Function to check and recreate the collection
def check_and_create_collection():
    try:
        # Check if the collection exists
        existing_collections = db.list_collection_names()
        print("Existing collections:", existing_collections)
        
        if collection in existing_collections:
            print("Collection already exists. Dropping the collection...")
            db[collection].drop()  # Drop the existing collection
            print("Collection dropped.")

        # Create a new collection (MongoDB creates it automatically when we insert data)
        print("Collection recreated successfully!")
    except Exception as e:
        print("Error occurred while recreating the collection:", e)

# Function to load data into MongoDB
def load_data_to_mongodb():
    collection = db['NetflixUserbase']  
    
    # Prepare data for insertion
    records = df.to_dict(orient='records')
    
    try:
        # Insert all records at once
        collection.insert_many(records)
        print("Data successfully loaded into MongoDB.")
    except Exception as e:
        print(f"Error inserting data: {e}")

# %%
# Function to test read consistency
def test_read_consistency(user_id):
    collection = db['NetflixUserbase']  
    
    # Strongly Consistent Read (default for MongoDB)
    start_time = time.time()
    strongly_consistent_read = collection.find_one({'UserID': str(user_id)})
    latency_strong = time.time() - start_time
    
    # Eventual Consistent Read (from secondary node, requires replica set)
    start_time = time.time()
    eventual_consistent_read = collection.with_options(read_preference=ReadPreference.SECONDARY_PREFERRED).find_one({'UserID': str(user_id)})
    latency_eventual = time.time() - start_time
    
    # Print results
    print("Strongly Consistent Read Result:", strongly_consistent_read)
    print("Strongly Consistent Read Latency:", latency_strong)
    print("Eventually Consistent Read Result:", eventual_consistent_read)
    print("Eventually Consistent Read Latency:", latency_eventual)

# %%
# Step 1: Check and recreate the collection
check_and_create_collection()

# Step 2: Load data into MongoDB
load_data_to_mongodb()

# Step 3: Test read consistency
test_read_consistency("3")  # Replace "3" with an appropriate UserID from your dataset
# Out:
# Existing collections: ['NetflixUserbase']
# Collection already exists. Dropping the collection...
# Collection dropped.
# Collection recreated successfully!
# Data successfully loaded into MongoDB.
# Strongly Consistent Read Result: None
# Strongly Consistent Read Latency: 0.01153874397277832
# Eventually Consistent Read Result: None
# Eventually Consistent Read Latency: 0.004715919494628906

# %%
from pymongo import MongoClient
import random
import time

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017')  
collection = db['NetflixUserbase']

# Generate and insert 100 records in batches
def insert_batch():
    records = []
    for i in range(100):  # Create 100 records
        new_record = {
            'UserID': i + 1,  
            'SubscriptionType': random.choice(['Basic', 'Standard', 'Premium']),
            'MonthlyRevenue': random.uniform(5.99, 14.99),
            'JoinDate': '2024-11-29',
            'LastPaymentDate': '2024-11-29',
            'Country': random.choice(['USA', 'Canada', 'UK', 'India']),
            'Age': random.randint(18, 60),
            'Gender': random.choice(['Male', 'Female', 'Other']),
            'Device': random.choice(['Phone', 'Tablet', 'PC']),
            'PlanDuration': random.randint(1, 12)
        }
        records.append(new_record)

    # Record the start time for insertion
    start_time = time.time()
    
    # Insert batch into MongoDB
    result = collection.insert_many(records)
    
    # Calculate the time taken
    insertion_time = time.time() - start_time
    
    # Print the number of records inserted and the time taken for insertion
    print(f"Successfully inserted {len(records)} records into MongoDB.")
    print(f"Time taken for bulk insertion: {insertion_time:.4f} seconds.")

# Insert 100 records
insert_batch()

# Query to retrieve records sorted by UserID (ascending order)
sorted_records = collection.find().sort('UserID', 1)  # 1 for ascending order

# Print the sorted records
for record in sorted_records:
    print(record)
# Out:
# Successfully inserted 100 records into MongoDB.
# Time taken for bulk insertion: 0.0057 seconds.
# {'_id': ObjectId('674e998ca3607d20ad85c9ca'), 'User ID': 1, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '15-01-22', 'Last Payment Date': '10-06-23', 'Country': 'United States', 'Age': 28, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9cb'), 'User ID': 2, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '05-09-21', 'Last Payment Date': '22-06-23', 'Country': 'Canada', 'Age': 35, 'Gender': 'Female', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9cc'), 'User ID': 3, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '28-02-23', 'Last Payment Date': '27-06-23', 'Country': 'United Kingdom', 'Age': 42, 'Gender': 'Male', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9cd'), 'User ID': 4, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '10-07-22', 'Last Payment Date': '26-06-23', 'Country': 'Australia', 'Age': 51, 'Gender': 'Female', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9ce'), 'User ID': 5, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '01-05-23', 'Last Payment Date': '28-06-23', 'Country': 'Germany', 'Age': 33, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9cf'), 'User ID': 6, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '18-03-22', 'Last Payment Date': '27-06-23', 'Country': 'France', 'Age': 29, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d0'), 'User ID': 7, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '09-12-21', 'Last Payment Date': '25-06-23', 'Country': 'Brazil', 'Age': 46, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d1'), 'User ID': 8, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '02-04-23', 'Last Payment Date': '24-06-23', 'Country': 'Mexico', 'Age': 39, 'Gender': 'Female', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d2'), 'User ID': 9, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '20-10-22', 'Last Payment Date': '23-06-23', 'Country': 'Spain', 'Age': 37, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d3'), 'User ID': 10, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '07-01-23', 'Last Payment Date': '22-06-23', 'Country': 'Italy', 'Age': 44, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d4'), 'User ID': 11, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '16-05-22', 'Last Payment Date': '22-06-23', 'Country': 'United States', 'Age': 31, 'Gender': 'Female', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d5'), 'User ID': 12, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '23-03-23', 'Last Payment Date': '28-06-23', 'Country': 'Canada', 'Age': 45, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d6'), 'User ID': 13, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '30-11-21', 'Last Payment Date': '27-06-23', 'Country': 'United Kingdom', 'Age': 48, 'Gender': 'Female', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d7'), 'User ID': 14, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '01-08-22', 'Last Payment Date': '26-06-23', 'Country': 'Australia', 'Age': 27, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d8'), 'User ID': 15, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '09-05-23', 'Last Payment Date': '28-06-23', 'Country': 'Germany', 'Age': 38, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9d9'), 'User ID': 16, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '07-04-22', 'Last Payment Date': '27-06-23', 'Country': 'France', 'Age': 36, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9da'), 'User ID': 17, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '24-01-22', 'Last Payment Date': '25-06-23', 'Country': 'Brazil', 'Age': 30, 'Gender': 'Female', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9db'), 'User ID': 18, 'Subscription Type': 'Standard', 'Monthly Revenue': 12, 'Join Date': '18-10-21', 'Last Payment Date': '24-06-23', 'Country': 'Mexico', 'Age': 43, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9dc'), 'User ID': 19, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '15-02-23', 'Last Payment Date': '23-06-23', 'Country': 'Spain', 'Age': 32, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c9dd'), 'User ID': 20, 'Subscription Type': 'Basic', 'Monthly Revenue': 10, 'Join Date': '27-05-23', 'Last Payment Date': '22-06-23', 'Country': 'Italy', 'Age': 41, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85c
 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4a'), 'User ID': 129, 'Subscription Type': 'Standard', 'Monthly Revenue': 13, 'Join Date': '05-11-22', 'Last Payment Date': '23-06-23', 'Country': 'Spain', 'Age': 38, 'Gender': 'Male', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4b'), 'User ID': 130, 'Subscription Type': 'Basic', 'Monthly Revenue': 14, 'Join Date': '07-01-23', 'Last Payment Date': '23-06-23', 'Country': 'Italy', 'Age': 43, 'Gender': 'Female', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4c'), 'User ID': 131, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '06-10-22', 'Last Payment Date': '23-06-23', 'Country': 'United States', 'Age': 47, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4d'), 'User ID': 132, 'Subscription Type': 'Basic', 'Monthly Revenue': 15, 'Join Date': '24-06-22', 'Last Payment Date': '28-06-23', 'Country': 'Canada', 'Age': 48, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4e'), 'User ID': 133, 'Subscription Type': 'Standard', 'Monthly Revenue': 13, 'Join Date': '24-06-22', 'Last Payment Date': '26-06-23', 'Country': 'United Kingdom', 'Age': 47, 'Gender': 'Male', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca4f'), 'User ID': 134, 'Subscription Type': 'Premium', 'Monthly Revenue': 15, 'Join Date': '05-11-22', 'Last Payment Date': '25-06-23', 'Country': 'Australia', 'Age': 32, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca50'), 'User ID': 135, 'Subscription Type': 'Basic', 'Monthly Revenue': 13, 'Join Date': '18-07-22', 'Last Payment Date': '26-06-23', 'Country': 'Germany', 'Age': 47, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca51'), 'User ID': 136, 'Subscription Type': 'Premium', 'Monthly Revenue': 12, 'Join Date': '13-09-22', 'Last Payment Date': '26-06-23', 'Country': 'France', 'Age': 41, 'Gender': 'Female', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca52'), 'User ID': 137, 'Subscription Type': 'Basic', 'Monthly Revenue': 12, 'Join Date': '10-08-22', 'Last Payment Date': '22-06-23', 'Country': 'Brazil', 'Age': 49, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca53'), 'User ID': 138, 'Subscription Type': 'Standard', 'Monthly Revenue': 15, 'Join Date': '21-09-22', 'Last Payment Date': '23-06-23', 'Country': 'Mexico', 'Age': 28, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca54'), 'User ID': 139, 'Subscription Type': 'Standard', 'Monthly Revenue': 13, 'Join Date': '24-03-23', 'Last Payment Date': '23-06-23', 'Country': 'Spain', 'Age': 40, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca55'), 'User ID': 140, 'Subscription Type': 'Basic', 'Monthly Revenue': 12, 'Join Date': '02-05-22', 'Last Payment Date': '23-06-23', 'Country': 'Italy', 'Age': 43, 'Gender': 'Female', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca56'), 'User ID': 141, 'Subscription Type': 'Premium', 'Monthly Revenue': 12, 'Join Date': '11-05-22', 'Last Payment Date': '27-06-23', 'Country': 'United States', 'Age': 42, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca57'), 'User ID': 142, 'Subscription Type': 'Basic', 'Monthly Revenue': 14, 'Join Date': '10-06-22', 'Last Payment Date': '22-06-23', 'Country': 'Canada', 'Age': 28, 'Gender': 'Male', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca58'), 'User ID': 143, 'Subscription Type': 'Standard', 'Monthly Revenue': 14, 'Join Date': '31-08-22', 'Last Payment Date': '24-06-23', 'Country': 'United Kingdom', 'Age': 30, 'Gender': 'Female', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca59'), 'User ID': 144, 'Subscription Type': 'Premium', 'Monthly Revenue': 10, 'Join Date': '17-08-22', 'Last Payment Date': '26-06-23', 'Country': 'Australia', 'Age': 33, 'Gender': 'Male', 'Device': 'Smart TV', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85
 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca6c'), 'User ID': 163, 'Subscription Type': 'Standard', 'Monthly Revenue': 11, 'Join Date': '05-04-22', 'Last Payment Date': '26-06-23', 'Country': 'United Kingdom', 'Age': 29, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca6d'), 'User ID': 164, 'Subscription Type': 'Basic', 'Monthly Revenue': 11, 'Join Date': '11-03-22', 'Last Payment Date': '26-06-23', 'Country': 'Australia', 'Age': 42, 'Gender': 'Female', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca6e'), 'User ID': 165, 'Subscription Type': 'Standard', 'Monthly Revenue': 14, 'Join Date': '25-05-22', 'Last Payment Date': '25-06-23', 'Country': 'Germany', 'Age': 49, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca6f'), 'User ID': 166, 'Subscription Type': 'Premium', 'Monthly Revenue': 13, 'Join Date': '16-04-22', 'Last Payment Date': '26-06-23', 'Country': 'France', 'Age': 42, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca70'), 'User ID': 167, 'Subscription Type': 'Basic', 'Monthly Revenue': 13, 'Join Date': '07-04-22', 'Last Payment Date': '24-06-23', 'Country': 'Brazil', 'Age': 29, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca71'), 'User ID': 168, 'Subscription Type': 'Standard', 'Monthly Revenue': 10, 'Join Date': '11-12-22', 'Last Payment Date': '28-06-23', 'Country': 'Mexico', 'Age': 29, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca72'), 'User ID': 169, 'Subscription Type': 'Premium', 'Monthly Revenue': 12, 'Join Date': '20-01-23', 'Last Payment Date': '26-06-23', 'Country': 'Spain', 'Age': 49, 'Gender': 'Male', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca73'), 'User ID': 170, 'Subscription Type': 'Basic', 'Monthly Revenue': 14, 'Join Date': '12-01-23', 'Last Payment Date': '25-06-23', 'Country': 'Italy', 'Age': 32, 'Gender': 'Male', 'Device': 'Laptop', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca74'), 'User ID': 171, 'Subscription Type': 'Premium', 'Monthly Revenue': 11, 'Join Date': '29-04-22', 'Last Payment Date': '24-06-23', 'Country': 'United States', 'Age': 35, 'Gender': 'Female', 'Device': 'Tablet', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca75'), 'User ID': 172, 'Subscription Type': 'Basic', 'Monthly Revenue': 12, 'Join Date': '27-04-22', 'Last Payment Date': '26-06-23', 'Country': 'Canada', 'Age': 39, 'Gender': 'Female', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# {'_id': ObjectId('674e998ca3607d20ad85ca76'), 'User ID': 173, 'Subscription Type': 'Standard', 'Monthly Revenue': 15, 'Join Date': '03-06-22', 'Last Payment Date': '25-06-23', 'Country': 'United Kingdom', 'Age': 40, 'Gender': 'Male', 'Device': 'Smartphone', 'Plan Duration': '1 Month'}
# ...
# {'_id': ObjectId('674e998ca3607d20ad85d3b9'), 'UserID': 43, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 10.50420004625719, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 30, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3ba'), 'UserID': 44, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 6.365098262459491, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 52, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 8}
# {'_id': ObjectId('674e998ca3607d20ad85d3bb'), 'UserID': 45, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 6.8647944247283705, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 51, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 5}
# {'_id': ObjectId('674e998ca3607d20ad85d3bc'), 'UserID': 46, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 8.358695816733864, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 38, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 8}
# {'_id': ObjectId('674e998ca3607d20ad85d3bd'), 'UserID': 47, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 12.508356679479018, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 40, 'Gender': 'Other', 'Device': 'Phone', 'PlanDuration': 4}
# {'_id': ObjectId('674e998ca3607d20ad85d3be'), 'UserID': 48, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 12.25828309683026, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 35, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 5}
# {'_id': ObjectId('674e998ca3607d20ad85d3bf'), 'UserID': 49, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 8.013986319140624, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 21, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 9}
# {'_id': ObjectId('674e998ca3607d20ad85d3c0'), 'UserID': 50, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 6.4981642381737785, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 32, 'Gender': 'Male', 'Device': 'Tablet', 'PlanDuration': 5}
# {'_id': ObjectId('674e998ca3607d20ad85d3c1'), 'UserID': 51, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.307743183696951, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 34, 'Gender': 'Other', 'Device': 'PC', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3c2'), 'UserID': 52, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 11.72927267604652, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 35, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 4}
# {'_id': ObjectId('674e998ca3607d20ad85d3c3'), 'UserID': 53, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 7.312234944056015, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 53, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 12}
# {'_id': ObjectId('674e998ca3607d20ad85d3c4'), 'UserID': 54, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 13.548555827337829, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 24, 'Gender': 'Other', 'Device': 'PC', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3c5'), 'UserID': 55, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 11.358767304830867, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 35, 'Gender': 'Other', 'Device': 'PC', 'PlanDuration': 8}
# {'_id': ObjectId('674e998ca3607d20ad85d3c6'), 'UserID': 56, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 11.093676858932525, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 20, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3c7'), 'UserID': 57, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 14.166803247663584, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 22, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3c8'), 'UserID': 58, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 12.046461562542655, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 49, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 9}
# {'_id': ObjectId('674e998ca3607d20ad85d3c9'), 'UserID': 59, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 7.642653722418306, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 56, 'Gender': 'Other', 'Device': 'PC', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3ca'), 'UserID': 60, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 9.753005395331666, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 28, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 2}
# {'_id': ObjectId('674e998ca3607d20ad85d3cb'), 'UserID': 61, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 13.16830764248661, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 59, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3cc'), 'UserID': 62, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 11.661724804434288, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 23, 'Gender': 'Other', 'Device': 'Phone', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3cd'), 'UserID': 63, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 9.298480002617245, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 36, 'Gender': 'Male', 'Device': 'Tablet', 'PlanDuration': 9}
# {'_id': ObjectId('674e998ca3607d20ad85d3ce'), 'UserID': 64, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 14.543042459703706, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 22, 'Gender': 'Male', 'Device': 'PC', 'PlanDuration': 12}
# {'_id': ObjectId('674e998ca3607d20ad85d3cf'), 'UserID': 65, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 9.782701281469013, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 29, 'Gender': 'Other', 'Device': 'Phone', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3d0'), 'UserID': 66, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 14.577411113442645, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 26, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 12}
# {'_id': ObjectId('674e998ca3607d20ad85d3d1'), 'UserID': 67, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.653240223472998, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 56, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3d2'), 'UserID': 68, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 13.353651390113363, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 33, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 4}
# {'_id': ObjectId('674e998ca3607d20ad85d3d3'), 'UserID': 69, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 13.180402115436209, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 24, 'Gender': 'Male', 'Device': 'Tablet', 'PlanDuration': 7}
# {'_id': ObjectId('674e998ca3607d20ad85d3d4'), 'UserID': 70, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 9.198900729447647, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 34, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3d5'), 'UserID': 71, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 9.156203871644724, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 28, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 7}
# {'_id': ObjectId('674e998ca3607d20ad85d3d6'), 'UserID': 72, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 8.987187949104332, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 60, 'Gender': 'Male', 'Device': 'PC', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3d7'), 'UserID': 73, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.798310679813051, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 46, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 7}
# {'_id': ObjectId('674e998ca3607d20ad85d3d8'), 'UserID': 74, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 7.244719591574876, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 24, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 9}
# {'_id': ObjectId('674e998ca3607d20ad85d3d9'), 'UserID': 75, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 13.613317500300656, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 46, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 1}
# {'_id': ObjectId('674e998ca3607d20ad85d3da'), 'UserID': 76, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 13.20578316207552, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 51, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 2}
# {'_id': ObjectId('674e998ca3607d20ad85d3db'), 'UserID': 77, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 11.910114330129527, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 22, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3dc'), 'UserID': 78, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 6.958961295358651, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 29, 'Gender': 'Male', 'Device': 'Tablet', 'PlanDuration': 3}
# {'_id': ObjectId('674e998ca3607d20ad85d3dd'), 'UserID': 79, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 8.953384528087126, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 41, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 2}
# {'_id': ObjectId('674e998ca3607d20ad85d3de'), 'UserID': 80, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 14.245423777769416, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 35, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3df'), 'UserID': 81, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.407123554055916, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 20, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3e0'), 'UserID': 82, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 7.546815146828026, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 23, 'Gender': 'Male', 'Device': 'Tablet', 'PlanDuration': 5}
# {'_id': ObjectId('674e998ca3607d20ad85d3e1'), 'UserID': 83, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 7.541508337142805, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 22, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3e2'), 'UserID': 84, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 7.4308151463785315, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 47, 'Gender': 'Male', 'Device': 'PC', 'PlanDuration': 7}
# {'_id': ObjectId('674e998ca3607d20ad85d3e3'), 'UserID': 85, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.033439263892143, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 44, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3e4'), 'UserID': 86, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 8.660542360089734, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 36, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 7}
# {'_id': ObjectId('674e998ca3607d20ad85d3e5'), 'UserID': 87, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 7.1534190414164325, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 55, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 9}
# {'_id': ObjectId('674e998ca3607d20ad85d3e6'), 'UserID': 88, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 12.01884151463386, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 28, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 8}
# {'_id': ObjectId('674e998ca3607d20ad85d3e7'), 'UserID': 89, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.6663314665400595, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 19, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 1}
# {'_id': ObjectId('674e998ca3607d20ad85d3e8'), 'UserID': 90, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 10.11118084850165, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 32, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 10}
# {'_id': ObjectId('674e998ca3607d20ad85d3e9'), 'UserID': 91, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 7.82697172606951, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 46, 'Gender': 'Female', 'Device': 'Phone', 'PlanDuration': 6}
# {'_id': ObjectId('674e998ca3607d20ad85d3ea'), 'UserID': 92, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 6.195315489951146, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 37, 'Gender': 'Male', 'Device': 'PC', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3eb'), 'UserID': 93, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 11.674759875848116, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 25, 'Gender': 'Male', 'Device': 'Phone', 'PlanDuration': 11}
# {'_id': ObjectId('674e998ca3607d20ad85d3ec'), 'UserID': 94, 'SubscriptionType': 'Premium', 'MonthlyRevenue': 10.988867437309189, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'UK', 'Age': 28, 'Gender': 'Female', 'Device': 'Tablet', 'PlanDuration': 3}
# {'_id': ObjectId('674e998ca3607d20ad85d3ed'), 'UserID': 95, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 6.4606068716900555, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 60, 'Gender': 'Other', 'Device': 'Tablet', 'PlanDuration': 4}
# {'_id': ObjectId('674e998ca3607d20ad85d3ee'), 'UserID': 96, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 7.224226500480381, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 20, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 5}
# {'_id': ObjectId('674e998ca3607d20ad85d3ef'), 'UserID': 97, 'SubscriptionType': 'Standard', 'MonthlyRevenue': 7.915726660746248, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 30, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 3}
# {'_id': ObjectId('674e998ca3607d20ad85d3f0'), 'UserID': 98, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 6.99136068879945, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'Canada', 'Age': 39, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 1}
# {'_id': ObjectId('674e998ca3607d20ad85d3f1'), 'UserID': 99, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 8.949446153102848, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'USA', 'Age': 50, 'Gender': 'Other', 'Device': 'Phone', 'PlanDuration': 4}
# {'_id': ObjectId('674e998ca3607d20ad85d3f2'), 'UserID': 100, 'SubscriptionType': 'Basic', 'MonthlyRevenue': 7.825484057837213, 'JoinDate': '2024-11-29', 'LastPaymentDate': '2024-11-29', 'Country': 'India', 'Age': 47, 'Gender': 'Female', 'Device': 'PC', 'PlanDuration': 3}
